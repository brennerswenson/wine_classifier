# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from subprocess import check_output
# %config InlineBackend.figure_format = 'retina'
from sklearn.preprocessing import Imputer, StandardScaler
from sklearn.metrics import fbeta_score, accuracy_score, make_scorer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score

# %% [markdown]
# #### Questions to answer:
# 1. On average, which type of grape is most expensive?
# 2. Which country produces the highest proportion of expensive wines?
# 3. Which characteristic is most important when classifying the type of grape?

# %%
# read in the first 150k rows of wine data
first_data_raw = pd.read_csv('winemag-data_first150k.csv')
first_data_raw.drop('Unnamed: 0', inplace=True, axis=1) # remove un-needed column

# load in second data set

second_data_raw = pd.read_csv('winemag-data-130k-v2.csv')
second_data_raw.drop(['Unnamed: 0', 'taster_name', 'taster_twitter_handle', 'title'], inplace=True, axis=1) # remove un-needed column
print('Raw DF shape: {}'.format(first_data_raw.shape))
display(first_data_raw.head())
# Out:
# Raw DF shape: (150930, 10)
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
second_data_raw.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         variety               winery
# 0                 Etna                NaN     White Blend              Nicosia
# 1                  NaN                NaN  Portuguese Red  Quinta dos Avidagos
# 2    Willamette Valley  Willamette Valley      Pinot Gris            Rainstorm
# 3  Lake Michigan Shore                NaN        Riesling           St. Julian
# 4    Willamette Valley  Willamette Valley      Pinot Noir         Sweet Cheeks

# %%
# create a concatenated dataframe with both datasets
data_raw = pd.concat([first_data_raw, second_data_raw], ignore_index=True)

# %%
# How many NaNs are in our dataset?
print('NaNs per column')
print(data_raw.isnull().sum().sort_values(ascending=False))
# Out:
# NaNs per column
# region_2       169437
# designation     83200
# region_1        46307
# price           22691
# province           68
# country            68
# variety             1
# winery              0
# points              0
# description         0
# dtype: int64

# %%
# Looks like Region 2 has by far the most NaNs. 
# Designation won't be used in our analysis as it includes natural language
data_raw.drop(['designation', 'region_2' ], inplace=True, axis=1) # drop two highest NaN columns

# %%
# Take another look at the NaNs
print('Shape with two columns removed: {}'.format(data_raw.shape))
print('NaNs per column')
NaNs = data_raw.isnull().sum().sort_values(ascending=False)
print(NaNs)
# Out:
# Shape with two columns removed: (280901, 8)
# NaNs per column
# region_1       46307
# price          22691
# province          68
# country           68
# variety            1
# winery             0
# points             0
# description        0
# dtype: int64

# %%
# How much of the columns are missing?
for col in NaNs.index[:2]:
    print('{:.2%} of values missing for'.format(NaNs[col]/data_raw.shape[0]), col)
# Out:
# 16.49% of values missing for region_1
# 8.08% of values missing for price

# %% [markdown]
# ### These proportions are not too drastic, we will impute the mean of the price after the data has been divided into expensive/inexpensive segments. We will not use the region in our models but will keep it in our data for reference later if needed

# %%
# are there any duplicate rows? 
print('{} duplicate rows'.format(data_raw.duplicated().sum()))
# Out:
# 111125 duplicate rows

# %%
# drop duplicate rows
data = data_raw.drop_duplicates()

# %%
print('Shape with duplicates removed: {}'.format(data.shape))
# Out:
# Shape with duplicates removed: (169776, 8)

# %%
print('Removed {:,} duplicates from original data'.format(data_raw.shape[0] - data.shape[0]))
# Out:
# Removed 111,125 duplicates from original data

# %%
# create subset of data with wines priced over a certain threshold
expensive_price_threshold = 75
expensive = data[data['price'] > expensive_price_threshold]

# sample of the dataframe
display(expensive.sample(5))
# Out:
#           country                                        description  points  \
# 72891   Australia  The 2009 Diana Madeline is 88% Cabernet Sauvig...      91
# 63813          US  Nearly all Merlot, with just 5% Cab Sauvignon,...      85
# 163070     Canada  Oculus is 71% Merlot, with 16% Cabernet Sauvig...      91
# 251603     France  This fine dry style of rosé with its crisp red...      92
# 21926       Italy  This brunello offers a pretty bouquet, showing...      92
#
#         price           province                region_1  \
# 72891    95.0  Western Australia          Margaret River
# 63813    80.0         California      Oak Knoll District
# 163070  120.0   British Columbia         Okanagan Valley
# 251603  130.0          Champagne               Champagne
# 21926    90.0            Tuscany  Brunello di Montalcino
#
#                          variety               winery
# 72891   Bordeaux-style Red Blend               Cullen
# 63813   Bordeaux-style Red Blend  Blackbird Vineyards
# 163070  Bordeaux-style Red Blend         Mission Hill
# 251603           Champagne Blend               Lanson
# 21926          Sangiovese Grosso   Fattoria dei Barbi

# %%
# how many NaNs in the expensive dataset?
expensive_NaNs = expensive.isnull().sum().sort_values(ascending=False)
print('Shape of expensive data: {}'.format(expensive.shape))
print(expensive_NaNs)
# Out:
# Shape of expensive data: (9616, 8)
# region_1       874
# winery           0
# variety          0
# province         0
# price            0
# points           0
# description      0
# country          0
# dtype: int64

# %% [markdown]
# ### Great! By happenstance, none of the wines with a price higher than USD 50 have any missing price data points

# %%
# create a DF with the value counts of each grape variety
variety_counts = expensive['variety'].value_counts().to_frame()
print('10 highest represented grape varieties with price more than $50')
display(variety_counts[:10])
# Out:
# 10 highest represented grape varieties with price more than $50
#                           variety
# Cabernet Sauvignon           1938
# Pinot Noir                   1180
# Bordeaux-style Red Blend      771
# Chardonnay                    709
# Red Blend                     692
# Nebbiolo                      657
# Champagne Blend               424
# Sangiovese                    355
# Syrah                         299
# Riesling                      257

# %%
# let's remind ourselves what the data looks like
display(expensive.sample(10))
# Out:
#          country                                        description  points  \
# 166441    France  The wine has so much structure and tension. It...      93
# 216287    France  This most powerful of Grand Cru vineyards has ...      96
# 35239     France  Mint aromas hint at the wood, but more importa...      95
# 265903  Portugal  The sweetness of the wine vies with the acidit...      99
# 176384        US  You'll want to age this wine for a while becau...      91
# 77692     France  This is rich, complex and full of ripe fruit. ...      92
# 24444      Italy  From a 300-acre property in Castellina in Chia...      92
# 21982      Italy  Huge, dark concentration makes this wine almos...      92
# 11031     France  This full-bodied wine packs in everything you'...      91
# 167451     Chile  Jammy berry aromas come in front of green, veg...      81
#
#         price      province                region_1                   variety  \
# 166441  113.0      Burgundy    Chassagne-Montrachet                Chardonnay
# 216287  496.0      Burgundy              Chambertin                Pinot Noir
# 35239   412.0      Bordeaux                Pauillac  Bordeaux-style Red Blend
# 265903  268.0          Port                     NaN                      Port
# 176384   90.0    California              Rutherford            Cabernet Franc
# 77692   110.0      Burgundy       Chambolle-Musigny                Pinot Noir
# 24444    90.0       Tuscany                 Toscana                    Merlot
# 21982    90.0       Tuscany  Brunello di Montalcino         Sangiovese Grosso
# 11031    85.0  Rhône Valley                Condrieu                  Viognier
# 167451   90.0  Maipo Valley                     NaN  Bordeaux-style Red Blend
#
#                       winery
# 166441      Olivier Leflaive
# 216287      Roche de Bellene
# 35239         Château Latour
# 265903       Taylor Fladgate
# 176384                  Peju
# 77692    Jean-Claude Boisset
# 24444   Tenuta Villa Trasqua
# 21982        Tenute Niccolai
# 11031     Les Vins de Vienne
# 167451     Viña el Principal

# %%
# calculate the standard deviation of each grape variety's price
variety_stds = expensive.groupby('variety').std().dropna()

# remove records where only one variety is present
variety_stds.columns = ['points_std', 'price_std']

# calculate mean of each grape variety
variety_means = expensive.groupby('variety').mean().dropna()

# rename columns
variety_means.columns = ['avg_points', 'avg_price']

# calculate median of each grape variety
variety_medians = expensive.groupby('variety').median().dropna()

# rename columns
variety_medians.columns = ['med_points', 'med_price']

# rename value_counts df column for merge
variety_counts.columns = ['variety_count']

# inner join on grape variety index
variety_stats = variety_stds.join(
    [variety_means, variety_medians, variety_counts], how='inner').sort_values(
        by='med_price', ascending=False)

# %%
variety_counts.shape
# Out:
# (168, 1)

# %%
variety_stats.shape
# Out:
# (121, 7)

# %% [markdown]
# 75 grape varieties only occured once in the data, so they are not included in the stats DF

# %% [markdown]
# #### 1. Out of our expensive subset, which grape variety tends to have the most expensive price point?

# %%
print('EXPENSIVE WINE DATA GROUPED BY GRAPE VARIETY')
display(variety_stats.head(10)) # DF is sorted by median price
# Out:
# EXPENSIVE WINE DATA GROUPED BY GRAPE VARIETY
#                                 points_std   price_std  avg_points  \
# Furmint                           1.414214  313.955411   95.000000
# Tempranillo-Cabernet Sauvignon    1.707825  271.584855   91.250000
# Muscadel                          2.828427  113.137085   95.000000
# Muscadelle                        2.629956  108.742816   96.250000
# Bual                              2.121320   25.455844   96.500000
# Silvaner                          3.130495   74.596917   90.600000
# Tinta de Toro                     1.947730   62.191886   93.642857
# Pedro Ximénez                     2.000000   72.762170   93.000000
# Malbec-Cabernet                   0.000000   24.748737   93.000000
# Petite Verdot                     3.000000   39.051248   91.000000
#
#                                  avg_price  med_points  med_price  \
# Furmint                         542.000000        95.0      542.0
# Tempranillo-Cabernet Sauvignon  317.500000        91.5      295.0
# Muscadel                        220.000000        95.0      220.0
# Muscadelle                      232.500000        96.0      220.0
# Bual                            212.000000        96.5      212.0
# Silvaner                        184.200000        90.0      177.0
# Tinta de Toro                   159.857143        94.0      159.0
# Pedro Ximénez                   175.666667        93.0      149.0
# Malbec-Cabernet                 147.500000        93.0      147.5
# Petite Verdot                   125.000000        91.0      145.0
#
#                                 variety_count
# Furmint                                     2
# Tempranillo-Cabernet Sauvignon              4
# Muscadel                                    2
# Muscadelle                                  4
# Bual                                        2
# Silvaner                                    5
# Tinta de Toro                              28
# Pedro Ximénez                               3
# Malbec-Cabernet                             2
# Petite Verdot                               3

# %% [markdown]
# It looks like the most expensive wines aren't very well-represented, which makes sense. The top five wines above, represented by median price, don't necessarily tell a lot as their mean is very close to the median, if not the same. We can see the `Tinto Fino` variety has a lot more data points, and are consistently priced highly. I would conclude that this variety of grape reliably produces wines that are on the more expensive side.

# %%
# Let's do the same analysis, but for country

# create a DF with the value counts of each grape's country
country_counts = expensive['country'].value_counts().to_frame()

# calculate the standard deviation of each grape country's price
country_stds = expensive.groupby('country').std().dropna()

# remove records where only one vcountry is present
country_stds.columns = ['points_std', 'price_std']

# calculate mean of each grape country
country_means = expensive.groupby('country').mean().dropna()

# rename columns
country_means.columns = ['avg_points', 'avg_price']

# calculate median of each grape country
country_medians = expensive.groupby('country').median().dropna()

# rename columns
country_medians.columns = ['med_points', 'med_price']

# rename value_counts df column for merge
country_counts.columns = ['variety_count']

# inner join on grape variety index
country_stats = country_stds.join(
    [country_means, country_medians, country_counts], how='inner').sort_values(
        by='variety_count', ascending=False)

# %% [markdown]
# #### 2. Which country produces the highest proportion of expensive wines?

# %%
print('EXPENSIVE WINE DATA GROUPED BY COUNTRY')
display(country_stats.head(10)) # DF is sorted by descending variety_count
# Out:
# EXPENSIVE WINE DATA GROUPED BY COUNTRY
#            points_std   price_std  avg_points   avg_price  med_points  \
# US           2.908787   57.650411   91.997684  112.917776        92.0
# France       2.442166  178.279933   92.712505  163.881822        93.0
# Italy        2.713761   69.858724   91.851515  120.430808        92.0
# Spain        2.898463   80.221118   91.628205  135.948718        92.0
# Australia    2.744597  113.223181   92.587629  140.601375        93.0
# Portugal     3.110157  133.111885   92.803279  143.778689        93.0
# Germany      2.909501  142.763957   92.394619  176.156951        93.0
# Argentina    1.927202   33.078351   91.824390  112.936585        92.0
# Chile        2.018330   62.642102   91.248227  115.900709        92.0
# Austria      2.141623   97.017119   93.589286  104.553571        94.0
#
#            med_price  variety_count
# US              95.0           3454
# France         111.0           2327
# Italy           98.0           1980
# Spain          110.0            468
# Australia      100.0            291
# Portugal       100.0            244
# Germany        111.0            223
# Argentina      100.0            205
# Chile           92.0            141
# Austria         90.0            112

# %% [markdown]
# Interestingly enough, I thought France would be the highest contributor to the expensive wine market, but the US more than doubles France's representation in the dataset. Compared to the US and Italy, France's `avg_price` is much further away than its respective median.
#
# France's price standard deviation is 3.5x that of the US, meaning that France produces a much larger variety in terms of price. (This affirms my preconceptions)

# %% [markdown]
# We never looked at the distribution of our data. Below is a plot that shows the distribution of price vs points, observing the trend between the two. On each axis you can see the distribution of each individual data series. The right hand distribution (price) shows that there is a large spike in the lower side of the price range, which makes sense. The points distribution seems to follow a normal distribution around a central mean. There is also a linear regression line plotted over the points.

# %%
# seaborn jointplot showing multiple distributions

sns.jointplot(
    x='points',
    y='price',
    data=expensive,
    kind='reg',
    color="#4CB391",
    height=10)
plt.title('Scatter Plot of Data with Axes Distributions');

# %% [markdown]
# Looking at these data we can see a trend between price and points. We can try to build a classifier to classify the grape variety based on all of the other features in the dataset.

# %%
# select only the columns that we want to create dummy variables with
x_split = expensive[['country', 'points', 'price', 'province', 'region_1', 'winery']]

# target value
y_split = expensive['variety']

# %%
# create dummy variables (1s and 0s for the categorical/text features)

x_split = pd.get_dummies(
    x_split, columns=['country', 'province', 'region_1', 'winery'])
y_split = pd.get_dummies(y_split, columns=['variety'])

# %%
# Here we see there are a LOT of columns, each one representing a categorical variable
print('X FEATURES')
display(x_split.sample(5))
print('TARGET LABEL')
display(y_split.sample(5))
# Out:
# X FEATURES
#         points  price  country_Argentina  country_Australia  country_Austria  \
# 31351       92   79.0                  0                  0                0
# 9878        88   79.0                  0                  0                0
# 103137      93  138.0                  0                  0                0
# 195930      96  220.0                  0                  0                0
# 86856       89   85.0                  0                  0                0
#
#         country_Bulgaria  country_Canada  country_Chile  country_England  \
# 31351                  0               0              0                0
# 9878                   0               0              0                0
# 103137                 0               0              0                0
# 195930                 0               0              0                0
# 86856                  0               0              0                0
#
#         country_France             ...              winery_Z. Alexander Brown  \
# 31351                0             ...                                      0
# 9878                 0             ...                                      0
# 103137               0             ...                                      0
# 195930               0             ...                                      0
# 86856                0             ...                                      0
#
#         winery_ZD  winery_Zenato  winery_Ziata  winery_Zorzal  \
# 31351           0              0             0              0
# 9878            0              0             0              0
# 103137          0              0             0              0
# 195930          0              0             0              0
# 86856           0              0             0              0
#
#         winery_Zuccardi  winery_Zymè  winery_iNapa Wine  winery_Ànima Negra  \
# 31351                 0            0                  0                   0
# 9878                  0            0                  0                   0
# 103137                0            0                  0                   0
# 195930                0            0                  0                   0
# 86856                 0            0                  0                   0
#
#         winery_Ökonomierat Rebholz
# 31351                            0
# 9878                             0
# 103137                           0
# 195930                           0
# 86856                            0
#
# [5 rows x 2829 columns]
# TARGET LABEL
#         Aglianico  Albariño  Alicante Bouschet  Alsace white blend  \
# 43394           0         0                  0                   0
# 198840          0         0                  0                   0
# 159743          0         0                  0                   0
# 210949          0         0                  0                   0
# 24230           0         0                  0                   0
#
#         Austrian Red Blend  Austrian white blend  Baga  Barbera  \
# 43394                    0                     0     0        0
# 198840                   0                     0     0        0
# 159743                   0                     0     0        0
# 210949                   0                     0     0        0
# 24230                    0                     0     0        0
#
#         Blaufränkisch  Bobal    ...      Traminer  Verdelho  Vermentino  \
# 43394               0      0    ...             0         0           0
# 198840              0      0    ...             0         0           0
# 159743              0      0    ...             0         0           0
# 210949              0      0    ...             0         0           0
# 24230               0      0    ...             0         0           0
#
#         Vidal Blanc  Viognier  Vitovska  Viura  Welschriesling  White Blend  \
# 43394             0         0         0      0               0            0
# 198840            0         0         0      0               0            0
# 159743            0         0         0      0               0            0
# 210949            0         0         0      0               0            0
# 24230             0         0         0      0               0            0
#
#         Zinfandel
# 43394           0
# 198840          0
# 159743          0
# 210949          0
# 24230           0
#
# [5 rows x 168 columns]

# %%
x_split = pd.DataFrame(StandardScaler().fit_transform(x_split),columns=x_split.columns)

# %%
x_split.sample(10)
# Out:
#         points     price  country_Argentina  country_Australia  \
# 0     1.398509  0.940201          -0.147591          -0.176653
# 1     1.398509 -0.188254          -0.147591          -0.176653
# 9601           -0.010198                   -0.010198
# 9602           -0.010198                   -0.010198
# 9603           -0.010198                   -0.010198
# 9604           -0.010198                   -0.010198
# 9605           -0.010198                   -0.010198
# 9606           -0.010198                   -0.010198
# 9607           -0.010198                   -0.010198
# 9608           -0.010198                   -0.010198
# 9609           -0.010198                   -0.010198
# 9610           -0.010198                   -0.010198
# 9611           -0.010198                   -0.010198
# 9612           -0.010198                   -0.010198
# 9613           -0.010198                   -0.010198
# 9614           -0.010198                   -0.010198
# 9615           -0.010198                   -0.010198
#
# [9616 rows x 2829 columns]

# %%
# split our data into training and testing data sets

X_train, X_test, y_train, y_test = train_test_split(
    x_split, y_split, random_state=1, test_size=0.2)

# %%
# impute the means for all missing values in the dataset
X_train = pd.DataFrame(
    Imputer().fit_transform(X_train), columns=x_split.columns)
X_test = pd.DataFrame(
    Imputer().fit_transform(X_test), columns=x_split.columns)

# %%
print('NUM OF NaNs IN IMPUTED DATA')
X_train.isnull().sum().sum()
# Out:
# NUM OF NaNs IN IMPUTED DATA
# 0

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier

# %%
# INSTANTIATE A RANDOM FOREST CLASSIFIER
clf = RandomForestClassifier()
preds = clf.fit(X_train, y_train).predict(X_test)
print('Accuracy of un-optimised model: {:2%}'.format(
    accuracy_score(y_test, preds)))
# Out:
# Accuracy of un-optimised model: 72.297297%

# %%
# GRID SEARCH CV TO OPTIMISE

param_grid = {
    'min_samples_leaf': [1, 2, 3],
    'n_estimators': [50, 100, 200],
    'n_jobs': [-1]
}

scorer = make_scorer(accuracy_score)

grid_obj = GridSearchCV(clf, param_grid, scoring=scorer, cv=10)

grid_fit = grid_obj.fit(X_train, y_train)

best_clf = grid_fit.best_estimator_

predictions = (clf.fit(X_train, y_train)).predict(X_test)
best_preds = best_clf.predict(X_test)

# %%
print('Accuracy of optimised model: {:2%}'.format(accuracy_score(y_test, best_preds)))
# Out:
# Accuracy of optimised model: 74.532225%

# %%
# OPTIMISED PARAMETERS
best_clf.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)>

# %%
# CREATE DICTIONARY OF FEATURE IMPORTANCES AND SORT THEM DESC

feats = {}
for feature, importance in zip(x_split.columns, best_clf.feature_importances_):
    feats[feature] = importance
importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-importance'}).sort_values(by='Gini-importance', ascending=False)

# %%
importances.head()
# Out:
#                      Gini-importance
# price                       0.090803
# points                      0.076835
# country_US                  0.028407
# province_California         0.028214
# province_Piedmont           0.027673

# %%
importances[:10].plot(kind='bar', rot=45)

# %%
results = 0
print_every = 50
for i in range(len(X_test)):
    pred = best_clf.predict(X_test.iloc[[i]])
    res = pd.DataFrame(pred, columns=y_test.columns)
    if i % print_every == 0 and i != 0:
        print('Running Accuracy: {:.2%}'.format((results / i)))
        print('{} vs {}'.format(
            res.idxmax(axis=1).values, y_test.iloc[[i]].idxmax(axis=1).values))
    if res.idxmax(axis=1).values == y_test.iloc[[i]].idxmax(axis=1).values:
        results += 1
    else:
        continue
print('Final accuracy: {}'.format(results/i))
# Out:
# Running Accuracy: 76.00%
# ['Bordeaux-style Red Blend'] vs ['Cabernet Sauvignon']
# Running Accuracy: 71.00%
# ['Malbec'] vs ['Malbec']
# Running Accuracy: 72.67%
# ['Cabernet Sauvignon'] vs ['Cabernet Sauvignon']
# Running Accuracy: 71.00%
# ['Cabernet Sauvignon'] vs ['Cabernet Sauvignon']
# Running Accuracy: 71.60%
# ['Nebbiolo'] vs ['Nebbiolo']
# Running Accuracy: 73.33%
# ['Red Blend'] vs ['Cabernet Sauvignon']
# Running Accuracy: 72.29%
# ['Nebbiolo'] vs ['Nebbiolo']
# Running Accuracy: 73.50%
# ['Port'] vs ['Port']
# Running Accuracy: 74.00%
# ['Sangiovese Grosso'] vs ['Sangiovese Grosso']
# Running Accuracy: 74.20%
# ['Nebbiolo'] vs ['Nebbiolo']
# Running Accuracy: 75.09%
# ['Bordeaux-style Red Blend'] vs ['Bordeaux-style Red Blend']
# Running Accuracy: 75.17%
# ['Red Blend'] vs ['Cabernet Sauvignon']
# Running Accuracy: 75.38%
# ['Chardonnay'] vs ['Chardonnay']
# Running Accuracy: 75.00%
# ['Red Blend'] vs ['Red Blend']
# Running Accuracy: 75.60%
# ['Aglianico'] vs ['Petit Verdot']
# Running Accuracy: 75.38%
# ['Riesling'] vs ['Riesling']
# Running Accuracy: 74.94%
# ['Shiraz'] vs ['Shiraz']
# Running Accuracy: 75.22%
# ['Champagne Blend'] vs ['Champagne Blend']
# Running Accuracy: 75.68%
# ['Pinot Noir'] vs ['Tempranillo']
# Running Accuracy: 75.50%
# ['Pinot Noir'] vs ['Pinot Noir']
# Running Accuracy: 75.43%
# ['Nebbiolo'] vs ['Nebbiolo']
# Running Accuracy: 75.45%
# ['Cabernet Sauvignon'] vs ['Cabernet Blend']
# Running Accuracy: 74.96%
# ['Bordeaux-style Red Blend'] vs ['Cabernet Sauvignon']
# Running Accuracy: 75.08%
# ['Nebbiolo'] vs ['Nebbiolo']
# Running Accuracy: 74.72%
# ['Viognier'] vs ['Viognier']
# Running Accuracy: 75.08%
# ['Aglianico'] vs ['Sparkling Blend']
# Running Accuracy: 74.59%
# ['Cabernet Sauvignon'] vs ['Cabernet Sauvignon']
# Running Accuracy: 74.14%
# ['Red Blend'] vs ['Red Blend']
# Running Accuracy: 74.34%
# ['Cabernet Sauvignon'] vs ['Cabernet Sauvignon']
# Running Accuracy: 74.27%
# ['Sangiovese'] vs ['Sangiovese']
# Running Accuracy: 74.19%
# ['Cabernet Sauvignon'] vs ['Cabernet Sauvignon']
# Running Accuracy: 74.25%
# ['Nebbiolo'] vs ['Nebbiolo']
# Running Accuracy: 74.18%
# ['Aglianico'] vs ['Riesling']
# Running Accuracy: 74.18%
# ['Pinot Noir'] vs ['Pinot Noir']
# Running Accuracy: 74.06%
# ['Pinot Noir'] vs ['Pinot Noir']
# Running Accuracy: 74.11%
# ['Portuguese Red'] vs ['Portuguese Red']
# Running Accuracy: 74.11%
# ['Sangiovese Grosso'] vs ['Sangiovese Grosso']
# Running Accuracy: 74.37%
# ['Syrah'] vs ['Syrah']
